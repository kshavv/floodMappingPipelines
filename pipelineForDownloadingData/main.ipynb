# %%
import ee
ee.Initialize(project='gentle-operator-308420')

# %%
import ee
credentials = ee.ServiceAccountCredentials(
    email='keshavrawat999.kr@gmail.com',
    key_file='/path/to/key.json',
)
ee.Initialize(credentials=credentials, project='your-project')

# %%
from flood_mapping import (
    download_temporal_images_for_year,
    download_temporal_images_for_years,
)

TRAINING_FC = 'projects/gentle-operator-308420/assets/finalDataset/full_dataset_v3'
ASSET_ROOT  = 'projects/gentle-operator-308420/assets/TemporalImages'

results = download_temporal_images_for_years(
    state='Assam',
    years=[2019, 2020, 2021, 2022, 2023, 2024],
    training_fc=TRAINING_FC,
    asset_root=ASSET_ROOT,
)
# Out:
# ━━ Year 2019 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImages/RF_water_FullYear_2019_assam
# ━━ Year 2020 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImages/RF_water_FullYear_2020_assam
# ━━ Year 2021 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImages/RF_water_FullYear_2021_assam
# ━━ Year 2022 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImages/RF_water_FullYear_2022_assam
# ━━ Year 2023 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   ♻ Full-year asset already exists, skipping: projects/gentle-operator-308420/assets/TemporalImages/RF_water_FullYear_2023_assam
# ━━ Year 2024 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImages/RF_water_FullYear_2024_assam
