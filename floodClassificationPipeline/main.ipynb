# %%
import ee
ee.Initialize(project='gentle-operator-308420')

# %%
# import ee
# credentials = ee.ServiceAccountCredentials(
#     email='keshavrawat999.kr@gmail.com',
#     key_file='/path/to/key.json',
# )
# ee.Initialize(credentials=credentials, project='your-project')

# %%
from flood_mapping import (
    download_temporal_images_for_years,
    classify_years,
)

# ── Config ────────────────────────────────────────────────────
STATE       = 'Bihar'
YEARS       = [2019, 2020, 2021, 2022, 2023, 2024]
ASSET_ROOT  = 'projects/gentle-operator-308420/assets/TemporalImagesNew'
TRAINING_FC = 'projects/gentle-operator-308420/assets/finalDataset/full_dataset_v3'


download_temporal_images_for_years(
    state=STATE,
    years=YEARS,
    training_fc=TRAINING_FC,
    asset_root=ASSET_ROOT,
    destinations='asset',
)
# Out:
# ━━ Year 2019 ━━
# Resolved admin region: AdminRoi(state="Bihar", whole_state, title="bihar")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2019_bihar
# ━━ Year 2020 ━━
# Resolved admin region: AdminRoi(state="Bihar", whole_state, title="bihar")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2020_bihar
# ━━ Year 2021 ━━
# Resolved admin region: AdminRoi(state="Bihar", whole_state, title="bihar")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2021_bihar
# ━━ Year 2022 ━━
# Resolved admin region: AdminRoi(state="Bihar", whole_state, title="bihar")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2022_bihar
# ━━ Year 2023 ━━
# Resolved admin region: AdminRoi(state="Bihar", whole_state, title="bihar")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2023_bihar
# ━━ Year 2024 ━━
# Resolved admin region: AdminRoi(state="Bihar", whole_state, title="bihar")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2024_bihar
# [{'admin': AdminRoi(state="Bihar", whole_state, title="bihar"),
#   'title': 'bihar',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2019_bihar',
#   'fullyear_asset_task': <Task V5DJIH3GLCEZN5POOFPF5KV7 Type.EXPORT_IMAGE: RF_water_FullYear_2019_bihar (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Bihar", whole_state, title="bihar"),
#   'title': 'bihar',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2020_bihar',
#   'fullyear_asset_task': <Task 5DFIXOSUIZS2MZSFHYHWGONA Type.EXPORT_IMAGE: RF_water_FullYear_2020_bihar (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Bihar", whole_state, title="bihar"),
#   'title': 'bihar',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2021_bihar',
#   'fullyear_asset_task': <Task YLRUFPL7D6UU6AQ7772TJ4UL Type.EXPORT_IMAGE: RF_water_FullYear_2021_bihar (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Bihar", whole_state, title="bihar"),
#   'title': 'bihar',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2022_bihar',
#   'fullyear_asset_task': <Task SFEJ62SJ7IPL4OKHT7VFS73H Type.EXPORT_IMAGE: RF_water_FullYear_2022_bihar (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Bihar", whole_state, title="bihar"),
#   'title': 'bihar',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2023_bihar',
#   'fullyear_asset_task': <Task 6AOI7T7QPRY6WFWXD3HERDHN Type.EXPORT_IMAGE: RF_water_FullYear_2023_bihar (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Bihar", whole_state, title="bihar"),
#   'title': 'bihar',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2024_bihar',
#   'fullyear_asset_task': <Task F2HF2GXC75FX5UFWEJNXTVG4 Type.EXPORT_IMAGE: RF_water_FullYear_2024_bihar (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []}]

# %%
from flood_mapping import (
    download_temporal_images_for_years,
    classify_years,
)

# ── Config ────────────────────────────────────────────────────
STATE       = 'Assam'
DISTRICTS   = ['Kamrup']  # Replace with your desired district(s), e.g., ['Barpeta', 'Cachar']
YEARS       = [2019, 2020, 2021, 2022, 2023, 2024]
ASSET_ROOT  = 'projects/gentle-operator-308420/assets/TemporalImagesNew'
TRAINING_FC = 'projects/gentle-operator-308420/assets/finalDataset/full_dataset_v3'


# ── Step 1: download (= export to EE asset) the full-year temporal stacks ──
# The asset title will be auto-derived based on the alphabetical index 
# of the district (e.g., RF_water_FullYear_<year>_assam_14)
# skip_existing=True (default) makes this idempotent.
download_temporal_images_for_years(
    state=STATE,
    districts=DISTRICTS,  # <--- Added districts parameter here
    years=YEARS,
    training_fc=TRAINING_FC,
    asset_root=ASSET_ROOT,
    destinations='asset',
)
# Out:
# ━━ Year 2019 ━━
# Resolved admin region: AdminRoi(state="Assam", districts=['Kamrup'], indices=[12], title="assam_12")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2019_assam_12
# ━━ Year 2020 ━━
# Resolved admin region: AdminRoi(state="Assam", districts=['Kamrup'], indices=[12], title="assam_12")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2020_assam_12
# ━━ Year 2021 ━━
# Resolved admin region: AdminRoi(state="Assam", districts=['Kamrup'], indices=[12], title="assam_12")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2021_assam_12
# ━━ Year 2022 ━━
# Resolved admin region: AdminRoi(state="Assam", districts=['Kamrup'], indices=[12], title="assam_12")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2022_assam_12
# ━━ Year 2023 ━━
# Resolved admin region: AdminRoi(state="Assam", districts=['Kamrup'], indices=[12], title="assam_12")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2023_assam_12
# ━━ Year 2024 ━━
# Resolved admin region: AdminRoi(state="Assam", districts=['Kamrup'], indices=[12], title="assam_12")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2024_assam_12
# [{'admin': AdminRoi(state="Assam", districts=['Kamrup'], indices=[12], title="assam_12"),
#   'title': 'assam_12',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2019_assam_12',
#   'fullyear_asset_task': <Task 7QRKL73E2YYFCYM53KJV5ICC Type.EXPORT_IMAGE: RF_water_FullYear_2019_assam_12 (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Assam", districts=['Kamrup'], indices=[12], title="assam_12"),
#   'title': 'assam_12',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2020_assam_12',
#   'fullyear_asset_task': <Task EYVDQ4BZKIATSO6CARD3UDYG Type.EXPORT_IMAGE: RF_water_FullYear_2020_assam_12 (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Assam", districts=['Kamrup'], indices=[12], title="assam_12"),
#   'title': 'assam_12',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2021_assam_12',
#   'fullyear_asset_task': <Task Q2MOUVGLU4SQEL5GDEGPCUK3 Type.EXPORT_IMAGE: RF_water_FullYear_2021_assam_12 (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Assam", districts=['Kamrup'], indices=[12], title="assam_12"),
#   'title': 'assam_12',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2022_assam_12',
#   'fullyear_asset_task': <Task M4RWBJBOVXCYONCWM2NDO46Y Type.EXPORT_IMAGE: RF_water_FullYear_2022_assam_12 (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Assam", districts=['Kamrup'], indices=[12], title="assam_12"),
#   'title': 'assam_12',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2023_assam_12',
#   'fullyear_asset_task': <Task ZNHPKK7DA7DSV3GM6E5IP44D Type.EXPORT_IMAGE: RF_water_FullYear_2023_assam_12 (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Assam", districts=['Kamrup'], indices=[12], title="assam_12"),
#   'title': 'assam_12',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2024_assam_12',
#   'fullyear_asset_task': <Task JRATOXWEYONMU54CJGYNDGS5 Type.EXPORT_IMAGE: RF_water_FullYear_2024_assam_12 (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []}]

# %%
# ── Step 2: classify each year into a 27-band Classified image ──
# One classification asset per year: Classified_<year>_kerala.
# Reads the full-year stacks Step 1 produced and writes state-shaped,
# polygon-masked output (no rectangle bounding boxes).

OUTPUT_ROOT = 'projects/gentle-operator-308420/assets/Classified'
ASSET_ROOT  = 'projects/gentle-operator-308420/assets/TemporalImagesNew'
STATE       = 'Assam'
YEARS       = [2024]

classify_years(
    state=STATE,
    years=YEARS,
    asset_root=ASSET_ROOT,
    destinations='asset',
    output_root=OUTPUT_ROOT,
)
# Out:
# ━━ Year 2024 ━━
# Resolved admin region: AdminRoi(state="Kerala", whole_state, title="kerala")
#   ✓ Queued classification → asset: projects/gentle-operator-308420/assets/Classified/Classified_2024_kerala
# [{'state': 'Kerala',
#   'title': 'kerala',
#   'year': 2024,
#   'classification': <ee.image.Image at 0x2125f8fa090>,
#   'target_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2024_kerala',
#   'historical_years': [2019, 2020, 2021, 2022, 2023, 2024],
#   'missing_historical': [],
#   'output_asset_id': 'projects/gentle-operator-308420/assets/Classified/Classified_2024_kerala',
#   'asset_task': <Task HCUVOP5BXY335T7M7IC2BLWR Type.EXPORT_IMAGE: Classified_2024_kerala (State.UNSUBMITTED)>,
#   'drive_task': None,
#   'drive_filename': None,
#   'skipped': []}]

# %%
# start the classification step
from flood_mapping import classify_years

# ── Config ────────────────────────────────────────────────────
OUTPUT_ROOT = 'projects/gentle-operator-308420/assets/Classified'
ASSET_ROOT  = 'projects/gentle-operator-308420/assets/TemporalImagesNew'
STATE       = 'Gujarat'
DISTRICTS   = ['Kamrup']  # Must perfectly match the list used in Step 1
YEARS       = [2019, 2020, 2021, 2022, 2023, 2024] 


# ── Step 2: classify each year into a 27-band Classified image ──
# Reads the full-year stacks Step 1 produced and writes district-shaped,
# polygon-masked output (no rectangle bounding boxes).
classify_years(
    state=STATE,
    # districts=DISTRICTS,  # <--- Pass the districts list here
    years=YEARS,
    asset_root=ASSET_ROOT,
    destinations='asset',
    output_root=OUTPUT_ROOT,
)
# Out:
# ━━ Year 2019 ━━
# Resolved admin region: AdminRoi(state="Gujarat", whole_state, title="gujarat")
#   ⚠ Missing historical full-year asset(s) for years [2024] (title="gujarat") — dropped from bi-week frequency. Using [2019, 2020, 2021, 2022, 2023].
#   ✓ Queued classification → asset: projects/gentle-operator-308420/assets/Classified/Classified_2019_gujarat
# ━━ Year 2020 ━━
# Resolved admin region: AdminRoi(state="Gujarat", whole_state, title="gujarat")
#   ⚠ Missing historical full-year asset(s) for years [2024] (title="gujarat") — dropped from bi-week frequency. Using [2019, 2020, 2021, 2022, 2023].
#   ✓ Queued classification → asset: projects/gentle-operator-308420/assets/Classified/Classified_2020_gujarat
# ━━ Year 2021 ━━
# Resolved admin region: AdminRoi(state="Gujarat", whole_state, title="gujarat")
#   ⚠ Missing historical full-year asset(s) for years [2024] (title="gujarat") — dropped from bi-week frequency. Using [2019, 2020, 2021, 2022, 2023].
#   ✓ Queued classification → asset: projects/gentle-operator-308420/assets/Classified/Classified_2021_gujarat
# ━━ Year 2022 ━━
# Resolved admin region: AdminRoi(state="Gujarat", whole_state, title="gujarat")
#   ⚠ Missing historical full-year asset(s) for years [2024] (title="gujarat") — dropped from bi-week frequency. Using [2019, 2020, 2021, 2022, 2023].
#   ✓ Queued classification → asset: projects/gentle-operator-308420/assets/Classified/Classified_2022_gujarat
# ━━ Year 2023 ━━
# Resolved admin region: AdminRoi(state="Gujarat", whole_state, title="gujarat")
#   ⚠ Missing historical full-year asset(s) for years [2024] (title="gujarat") — dropped from bi-week frequency. Using [2019, 2020, 2021, 2022, 2023].
#   ✓ Queued classification → asset: projects/gentle-operator-308420/assets/Classified/Classified_2023_gujarat
# ━━ Year 2024 ━━
# Resolved admin region: AdminRoi(state="Gujarat", whole_state, title="gujarat")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 15
#       9 YEARS       = [2019, 2020, 2021, 2022, 2023, 2024]
#      12 # ── Step 2: classify each year into a 27-band Classified image ──
#      13 # Reads the full-year stacks Step 1 produced and writes district-shaped,
#      14 # polygon-masked output (no rectangle bounding boxes).
# ---> 15 classify_years(
#      16     state=STATE,
#      17     # districts=DISTRICTS,  # <--- Pass the districts list here
#      18     years=YEARS,
#      19     asset_root=ASSET_ROOT,
#      20     destinations='asset',
#      21     output_root=OUTPUT_ROOT,
#      22 )
#
# File c:\Users\DELL\Desktop\ICTD_MTP_PROJECT\pipelines-floodModelling\floodClassificationPipeline\flood_mapping\classify_year.py:314, in classify_years(state, years, asset_root, **kwargs)
#     312 for yr in years:
#     313     print(f'━━ Year {yr} ━━')
# --> 314     results.append(classify_year(
#     315         state=state, year=yr, asset_root=asset_root, **kwargs))
#     316 return results
#
# File c:\Users\DELL\Desktop\ICTD_MTP_PROJECT\pipelines-floodModelling\floodClassificationPipeline\flood_mapping\classify_year.py:196, in classify_year(state, year, asset_root, districts, title, roi, historical_years, destinations, output_root, drive_folder, output_name, thresholds, apply_temporal_corrections, apply_geometry_mask, start_tasks, skip_existing)
#     194 target_id = fullyear_asset_id(asset_root, year, resolved_title)
#     195 if not _asset_exists(target_id):
# --> 196     raise FileNotFoundError(
#     197         f'Target full-year asset not found: {target_id}\n'
#     198         f'Run the download pipeline for year={year}, '
#     199         f'title="{resolved_title}" first.')
#     200 target_stack = ee.Image(target_id)
#     202 if resolved_roi is None:
#
# FileNotFoundError: Target full-year asset not found: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2024_gujarat
# Run the download pipeline for year=2024, title="gujarat" first.
