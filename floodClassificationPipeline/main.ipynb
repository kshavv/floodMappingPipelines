# %%
import ee
ee.Initialize(project='gentle-operator-308420')

# %%
# import ee
# credentials = ee.ServiceAccountCredentials(
#     email='keshavrawat999.kr@gmail.com',
#     key_file='/path/to/key.json',
# )
# ee.Initialize(credentials=credentials, project='your-project')

# %%
from flood_mapping import (
    download_temporal_images_for_years,
    classify_years,
)

# ── Config ────────────────────────────────────────────────────
STATE       = 'Assam'
YEARS       = [2019, 2020, 2021, 2022, 2023, 2024]
ASSET_ROOT  = 'projects/gentle-operator-308420/assets/TemporalImagesNew'
TRAINING_FC = 'projects/gentle-operator-308420/assets/finalDataset/full_dataset_v3'


download_temporal_images_for_years(
    state=STATE,
    years=YEARS,
    training_fc=TRAINING_FC,
    asset_root=ASSET_ROOT,
    destinations='asset',
)
# Out:
# ━━ Year 2019 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2019_assam
# ━━ Year 2020 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2020_assam
# ━━ Year 2021 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2021_assam
# ━━ Year 2022 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2022_assam
# ━━ Year 2023 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2023_assam
# ━━ Year 2024 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2024_assam
# [{'admin': AdminRoi(state="Assam", whole_state, title="assam"),
#   'title': 'assam',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2019_assam',
#   'fullyear_asset_task': <Task TLT3RNM6BDBC6XKHLRFOFAEQ Type.EXPORT_IMAGE: RF_water_FullYear_2019_assam (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Assam", whole_state, title="assam"),
#   'title': 'assam',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2020_assam',
#   'fullyear_asset_task': <Task 55ENIEV5P3YTLRR7SKUTCUQP Type.EXPORT_IMAGE: RF_water_FullYear_2020_assam (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Assam", whole_state, title="assam"),
#   'title': 'assam',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2021_assam',
#   'fullyear_asset_task': <Task NMVWD5U2PT2LVCWROPJVEHTY Type.EXPORT_IMAGE: RF_water_FullYear_2021_assam (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Assam", whole_state, title="assam"),
#   'title': 'assam',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2022_assam',
#   'fullyear_asset_task': <Task QTLFYFTBNQASRRVBVZOMRGMG Type.EXPORT_IMAGE: RF_water_FullYear_2022_assam (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Assam", whole_state, title="assam"),
#   'title': 'assam',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2023_assam',
#   'fullyear_asset_task': <Task X5SRD3XQHLR4CFO6ECCSWRVS Type.EXPORT_IMAGE: RF_water_FullYear_2023_assam (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Assam", whole_state, title="assam"),
#   'title': 'assam',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2024_assam',
#   'fullyear_asset_task': <Task OR6O54RYAZJ4HZIXUL4YX3H7 Type.EXPORT_IMAGE: RF_water_FullYear_2024_assam (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []}]

# %%
from flood_mapping import (
    download_temporal_images_for_years,
    classify_years,
)

# ── Config ────────────────────────────────────────────────────
STATE       = 'Assam'
DISTRICTS   = ['Kamrup']  # Replace with your desired district(s), e.g., ['Barpeta', 'Cachar']
YEARS       = [2019, 2020, 2021, 2022, 2023, 2024]
ASSET_ROOT  = 'projects/gentle-operator-308420/assets/TemporalImagesNew'
TRAINING_FC = 'projects/gentle-operator-308420/assets/finalDataset/full_dataset_v3'


# ── Step 1: download (= export to EE asset) the full-year temporal stacks ──
# The asset title will be auto-derived based on the alphabetical index 
# of the district (e.g., RF_water_FullYear_<year>_assam_14)
# skip_existing=True (default) makes this idempotent.
download_temporal_images_for_years(
    state=STATE,
    # districts=DISTRICTS,  # <--- Added districts parameter here
    years=YEARS,
    training_fc=TRAINING_FC,
    asset_root=ASSET_ROOT,
    destinations='asset',
)
# Out:
# ━━ Year 2019 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2019_assam
# ━━ Year 2020 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2020_assam
# ━━ Year 2021 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2021_assam
# ━━ Year 2022 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2022_assam
# ━━ Year 2023 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Using 2024 BW_1 as EOY anchor
#   ✓ Queued Full-year → asset: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2023_assam
# ━━ Year 2024 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
#   Smoothing: Previous year asset not found, using current BW_1 as BOY anchor
#   Smoothing: Next year asset not found, using current BW_27 as EOY anchor
#   ♻ Full-year asset already exists, skipping: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2024_assam
# [{'admin': AdminRoi(state="Assam", whole_state, title="assam"),
#   'title': 'assam',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2019_assam',
#   'fullyear_asset_task': <Task EPEGYB2AWITONHY4CWQGKLEN Type.EXPORT_IMAGE: RF_water_FullYear_2019_assam (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Assam", whole_state, title="assam"),
#   'title': 'assam',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2020_assam',
#   'fullyear_asset_task': <Task TGYMKZ6A5OGWWJOUR4YSEAJ7 Type.EXPORT_IMAGE: RF_water_FullYear_2020_assam (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Assam", whole_state, title="assam"),
#   'title': 'assam',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2021_assam',
#   'fullyear_asset_task': <Task 6FU4EU77A7LGBRBNGKC5WLX7 Type.EXPORT_IMAGE: RF_water_FullYear_2021_assam (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Assam", whole_state, title="assam"),
#   'title': 'assam',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2022_assam',
#   'fullyear_asset_task': <Task Z3XT3FAQMY526XSCHLTORTV5 Type.EXPORT_IMAGE: RF_water_FullYear_2022_assam (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Assam", whole_state, title="assam"),
#   'title': 'assam',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2023_assam',
#   'fullyear_asset_task': <Task Y7J7V3USQ3YXMBLANWCMVTKV Type.EXPORT_IMAGE: RF_water_FullYear_2023_assam (State.UNSUBMITTED)>,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': []},
#  {'admin': AdminRoi(state="Assam", whole_state, title="assam"),
#   'title': 'assam',
#   'fullyear_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2024_assam',
#   'fullyear_asset_task': None,
#   'fullyear_drive_task': None,
#   'fullyear_drive_filename': None,
#   'skipped': ['projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2024_assam']}]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# ── Step 2: classify each year into a 27-band Classified image ──
# One classification asset per year: Classified_<year>_kerala.
# Reads the full-year stacks Step 1 produced and writes state-shaped,
# polygon-masked output (no rectangle bounding boxes).
from flood_mapping import (
    download_temporal_images_for_years,
    classify_years,
)


OUTPUT_ROOT = 'projects/gentle-operator-308420/assets/Classified'
ASSET_ROOT  = 'projects/gentle-operator-308420/assets/TemporalImagesNew'
STATE       = 'Assam'
YEARS       = [2020]

classify_years(
    state=STATE,
    years=YEARS,
    asset_root=ASSET_ROOT,
    destinations='asset',
    output_root=OUTPUT_ROOT,
)
# Out:
# ━━ Year 2020 ━━
# Resolved admin region: AdminRoi(state="Assam", whole_state, title="assam")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 16
#      13 STATE       = 'Assam'
#      14 YEARS       = [2020]
# ---> 16 classify_years(
#      17     state=STATE,
#      18     years=YEARS,
#      19     asset_root=ASSET_ROOT,
#      20     destinations='asset',
#      21     output_root=OUTPUT_ROOT,
#      22 )
#
# File c:\Users\DELL\Desktop\ICTD_MTP_PROJECT\pipelines-floodModelling\floodClassificationPipeline\flood_mapping\classify_year.py:314, in classify_years(state, years, asset_root, **kwargs)
#     312 for yr in years:
#     313     print(f'━━ Year {yr} ━━')
# --> 314     results.append(classify_year(
#     315         state=state, year=yr, asset_root=asset_root, **kwargs))
#     316 return results
#
# File c:\Users\DELL\Desktop\ICTD_MTP_PROJECT\pipelines-floodModelling\floodClassificationPipeline\flood_mapping\classify_year.py:196, in classify_year(state, year, asset_root, districts, title, roi, historical_years, destinations, output_root, drive_folder, output_name, thresholds, apply_temporal_corrections, apply_geometry_mask, start_tasks, skip_existing)
#     194 target_id = fullyear_asset_id(asset_root, year, resolved_title)
#     195 if not _asset_exists(target_id):
# --> 196     raise FileNotFoundError(
#     197         f'Target full-year asset not found: {target_id}\n'
#     198         f'Run the download pipeline for year={year}, '
#     199         f'title="{resolved_title}" first.')
#     200 target_stack = ee.Image(target_id)
#     202 if resolved_roi is None:
#
# FileNotFoundError: Target full-year asset not found: projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2020_assam
# Run the download pipeline for year=2020, title="assam" first.

# %%
# start the classification step
from flood_mapping import classify_years

# ── Config ────────────────────────────────────────────────────
OUTPUT_ROOT = 'projects/gentle-operator-308420/assets/Classified'
ASSET_ROOT  = 'projects/gentle-operator-308420/assets/TemporalImagesNew'
STATE       = 'Bihar'
DISTRICTS   = ['Kamrup']  # Must perfectly match the list used in Step 1
YEARS       = [2019, 2020, 2021, 2022, 2023, 2024] 


# ── Step 2: classify each year into a 27-band Classified image ──
# Reads the full-year stacks Step 1 produced and writes district-shaped,
# polygon-masked output (no rectangle bounding boxes).
classify_years(
    state=STATE,
    # districts=DISTRICTS,  # <--- Pass the districts list here
    years=YEARS,
    asset_root=ASSET_ROOT,
    destinations='asset',
    output_root=OUTPUT_ROOT,
)
# Out:
# ━━ Year 2019 ━━
# Resolved admin region: AdminRoi(state="Bihar", whole_state, title="bihar")
#   ✓ Queued classification → asset: projects/gentle-operator-308420/assets/Classified/Classified_2019_bihar
# ━━ Year 2020 ━━
# Resolved admin region: AdminRoi(state="Bihar", whole_state, title="bihar")
#   ✓ Queued classification → asset: projects/gentle-operator-308420/assets/Classified/Classified_2020_bihar
# ━━ Year 2021 ━━
# Resolved admin region: AdminRoi(state="Bihar", whole_state, title="bihar")
#   ✓ Queued classification → asset: projects/gentle-operator-308420/assets/Classified/Classified_2021_bihar
# ━━ Year 2022 ━━
# Resolved admin region: AdminRoi(state="Bihar", whole_state, title="bihar")
#   ✓ Queued classification → asset: projects/gentle-operator-308420/assets/Classified/Classified_2022_bihar
# ━━ Year 2023 ━━
# Resolved admin region: AdminRoi(state="Bihar", whole_state, title="bihar")
#   ✓ Queued classification → asset: projects/gentle-operator-308420/assets/Classified/Classified_2023_bihar
# ━━ Year 2024 ━━
# Resolved admin region: AdminRoi(state="Bihar", whole_state, title="bihar")
#   ✓ Queued classification → asset: projects/gentle-operator-308420/assets/Classified/Classified_2024_bihar
# [{'state': 'Bihar',
#   'title': 'bihar',
#   'year': 2019,
#   'classification': <ee.image.Image at 0x255d63717c0>,
#   'target_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2019_bihar',
#   'historical_years': [2019, 2020, 2021, 2022, 2023, 2024],
#   'missing_historical': [],
#   'output_asset_id': 'projects/gentle-operator-308420/assets/Classified/Classified_2019_bihar',
#   'asset_task': <Task EGXY23LHIEYLAQXY6DX6XWLW Type.EXPORT_IMAGE: Classified_2019_bihar (State.UNSUBMITTED)>,
#   'drive_task': None,
#   'drive_filename': None,
#   'skipped': []},
#  {'state': 'Bihar',
#   'title': 'bihar',
#   'year': 2020,
#   'classification': <ee.image.Image at 0x255d644b260>,
#   'target_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2020_bihar',
#   'historical_years': [2019, 2020, 2021, 2022, 2023, 2024],
#   'missing_historical': [],
#   'output_asset_id': 'projects/gentle-operator-308420/assets/Classified/Classified_2020_bihar',
#   'asset_task': <Task MOKU2I7NH33PGOMWNW7IGVXJ Type.EXPORT_IMAGE: Classified_2020_bihar (State.UNSUBMITTED)>,
#   'drive_task': None,
#   'drive_filename': None,
#   'skipped': []},
#  {'state': 'Bihar',
#   'title': 'bihar',
#   'year': 2021,
#   'classification': <ee.image.Image at 0x255d65a0dd0>,
#   'target_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2021_bihar',
#   'historical_years': [2019, 2020, 2021, 2022, 2023, 2024],
#   'missing_historical': [],
#   'output_asset_id': 'projects/gentle-operator-308420/assets/Classified/Classified_2021_bihar',
#   'asset_task': <Task ODCXES2PJURHI3256WZAF5GA Type.EXPORT_IMAGE: Classified_2021_bihar (State.UNSUBMITTED)>,
#   'drive_task': None,
#   'drive_filename': None,
#   'skipped': []},
#  {'state': 'Bihar',
#   'title': 'bihar',
#   'year': 2022,
#   'classification': <ee.image.Image at 0x255d674e150>,
#   'target_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2022_bihar',
#   'historical_years': [2019, 2020, 2021, 2022, 2023, 2024],
#   'missing_historical': [],
#   'output_asset_id': 'projects/gentle-operator-308420/assets/Classified/Classified_2022_bihar',
#   'asset_task': <Task BR6BIMEW4ZFMZCL3A2GVLHHR Type.EXPORT_IMAGE: Classified_2022_bihar (State.UNSUBMITTED)>,
#   'drive_task': None,
#   'drive_filename': None,
#   'skipped': []},
#  {'state': 'Bihar',
#   'title': 'bihar',
#   'year': 2023,
#   'classification': <ee.image.Image at 0x255d6817830>,
#   'target_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2023_bihar',
#   'historical_years': [2019, 2020, 2021, 2022, 2023, 2024],
#   'missing_historical': [],
#   'output_asset_id': 'projects/gentle-operator-308420/assets/Classified/Classified_2023_bihar',
#   'asset_task': <Task HUZOPLA3V5QN4XVJHX3X2DYU Type.EXPORT_IMAGE: Classified_2023_bihar (State.UNSUBMITTED)>,
#   'drive_task': None,
#   'drive_filename': None,
#   'skipped': []},
#  {'state': 'Bihar',
#   'title': 'bihar',
#   'year': 2024,
#   'classification': <ee.image.Image at 0x255d6824440>,
#   'target_asset_id': 'projects/gentle-operator-308420/assets/TemporalImagesNew/RF_water_FullYear_2024_bihar',
#   'historical_years': [2019, 2020, 2021, 2022, 2023, 2024],
#   'missing_historical': [],
#   'output_asset_id': 'projects/gentle-operator-308420/assets/Classified/Classified_2024_bihar',
#   'asset_task': <Task ZMO77RR5TQQZ5SOOT3JQB4MD Type.EXPORT_IMAGE: Classified_2024_bihar (State.UNSUBMITTED)>,
#   'drive_task': None,
#   'drive_filename': None,
#   'skipped': []}]
